# %% [markdown]
# Import relevant Libaries

# %%
# !pip install pyarrow
# Out:
# Collecting pyarrow
#   Using cached pyarrow-11.0.0-cp39-cp39-win_amd64.whl (20.6 MB)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\nifu18ab\anaconda3\lib\site-packages (from pyarrow) (1.20.3)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-11.0.0

# %%
# Base libraries
import pandas as pd
import numpy as np
import os
import math as math
import datetime
from scipy import stats

# Visualizations
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# Set WD

# %%
import os
os.getcwd()
os.chdir('C:\\Users\\nifu18ab\\Desktop\\GEUS-Master-Thesis')
#os.chdir('/Users/nilsfulde/Desktop/GEUS-Master-Thesis')

# %% [markdown]
# **Load New Promice Data**

# %%
df = pd.read_parquet('data\\new_promice\\all_promice_data.parquet.gzip', engine='pyarrow')

# %%
df.columns.tolist()
# Out:
# ['index',
#  'stid',
#  'Datetime',
#  'p_u',
#  't_u',
#  'rh_u',
#  'rh_u_cor',
#  'qh_u',
#  'wspd_u',
#  'wdir_u',
#  'dsr',
#  'dsr_cor',
#  'usr',
#  'usr_cor',
#  'albedo',
#  'dlr',
#  'ulr',
#  'cc',
#  't_surf',
#  'dlhf_u',
#  'dshf_u',
#  'z_boom_u',
#  'z_stake',
#  'z_pt',
#  'z_pt_cor',
#  'precip_u',
#  'precip_u_cor',
#  't_i_1',
#  't_i_2',
#  't_i_3',
#  't_i_4',
#  't_i_5',
#  't_i_6',
#  't_i_7',
#  't_i_8',
#  'tilt_x',
#  'tilt_y',
#  'rot',
#  'gps_lat',
#  'gps_lon',
#  'gps_alt',
#  'gps_time',
#  'gps_geoid',
#  'gps_geounit',
#  'gps_hdop',
#  'gps_numsat',
#  'gps_q',
#  'batt_v',
#  'batt_v_ini',
#  'batt_v_ss',
#  'fan_dc_u',
#  'freq_vw',
#  't_log',
#  't_rad',
#  'msg_lat',
#  'msg_lon',
#  'z_surf_1',
#  'z_surf_2',
#  'z_surf_1_adj_flag',
#  'z_surf_2_adj_flag',
#  'z_surf_combined',
#  'depth_t_i_1',
#  'depth_t_i_2',
#  'depth_t_i_3',
#  'depth_t_i_4',
#  'depth_t_i_5',
#  'depth_t_i_6',
#  'depth_t_i_7',
#  'depth_t_i_8',
#  't_i_10m',
#  'p_l',
#  't_l',
#  'rh_l',
#  'rh_l_cor',
#  'qh_l',
#  'wspd_l',
#  'wdir_l',
#  'dlhf_l',
#  'dshf_l',
#  'z_boom_l',
#  'precip_l',
#  'precip_l_cor',
#  't_i_9',
#  't_i_10',
#  't_i_11',
#  'fan_dc_l',
#  'depth_t_i_9',
#  'depth_t_i_10',
#  'depth_t_i_11',
#  'z_pt_cor_adj_flag',
#  'z_pt_cor_adj',
#  'z_surf_1_adj',
#  'z_surf_2_adj',
#  'AirPressure(hPa)',
#  'AirTemperature(C)',
#  'RelativeHumidity(%)',
#  'RelativeHumidity_cor(%)',
#  'SpecificHumidity(g/kg)',
#  'WindSpeed(m/s)',
#  'WindDirection(d)',
#  'ShortwaveRadiationDown(W/m2)',
#  'ShortwaveRadiationDown_Cor(W/m2)',
#  'ShortwaveRadiationUp(W/m2)',
#  'ShortwaveRadiationUp_Cor(W/m2)',
#  'Albedo',
#  'LongwaveRadiationDown(W/m2)',
#  'LongwaveRadiationUp(W/m2)',
#  'CloudCover',
#  'SurfaceTemperature(C)',
#  'LatentHeatFlux(W/m2)',
#  'SensibleHeatFlux(W/m2)',
#  'HeightSensorBoom(m)',
#  'HeightStakes(m)',
#  'DepthPressureTransducer(m)',
#  'DepthPressureTransducer_Cor(m)',
#  'Precipitation',
#  'Precipitation_Cor',
#  'IceTemperature1(C)',
#  'IceTemperature2(C)',
#  'IceTemperature3(C)',
#  'IceTemperature4(C)',
#  'IceTemperature5(C)',
#  'IceTemperature6(C)',
#  'IceTemperature7(C)',
#  'IceTemperature8(C)',
#  'TiltToEast(d)',
#  'TiltToNorth(d)',
#  'Heading',
#  'LatitudeGPS(degN)',
#  'LongitudeGPS(degW)',
#  'ElevationGPS(m)',
#  'TimeGPS(hhmmssUTC)',
#  'HorDilOfPrecGPS',
#  'SnowHeight(m)',
#  'SurfaceHeight(m)',
#  'DepthPressureTransducer_Cor_adj(m)',
#  'SnowHeight_adj(m)',
#  'SurfaceHeight_adj(m)',
#  'SurfaceHeight1_adj(m)',
#  'SurfaceHeight2_adj(m)',
#  'SurfaceHeight_summary(m)',
#  'depth_1',
#  'depth_2',
#  'depth_3',
#  'depth_4',
#  'depth_5',
#  'depth_6',
#  'depth_7',
#  'depth_8',
#  'IceTemperature10m(C)',
#  'year',
#  'month',
#  'season',
#  'DayOfYear',
#  'DayOfCentury',
#  'day',
#  'hour',
#  'date']

# %%
df[['DepthPressureTransducer(m)',
       'DepthPressureTransducer_Cor(m)', 'DepthPressureTransducer_Cor_adj(m)',
    'depth_t_i_1',
 'depth_t_i_2',
 'depth_t_i_3',
 'depth_t_i_4',
 'depth_t_i_5',
 'depth_t_i_6',
 'depth_t_i_7',
 'depth_t_i_8',]].groupby(df.station_name).count()
# Out:
#               DepthPressureTransducer(m)  DepthPressureTransducer_Cor(m)  \
# station_name
# CEN1                                   0                               0
# CEN2                                   0                               0
# CP1                                    0                               0
# DY2                                    0                               0
# EGP                                    0                               0
# HUM                                    0                               0
# JAR                                    0                               0
# JAR_O                                  0                               0
# KAN_B                                  0                               0
# KAN_L                                  0                               0
# KAN_M                                  0                               0
# KAN_U                                  0                               0
# KPC_L                                  0                               0
# KPC_Lv3                                0                               0
# KPC_U                                  0                               0
# KPC_Uv3                                0                               0
# LYN_L                                  0                               0
# LYN_T                                  0                               0
# MIT                                    0                               0
# NAE                                    0                               0
# NAU                                    0                               0
# NEM                                    0                               0
# NSE                                    0                               0
# NUK_K                                  0                               0
# NUK_L                                  0                               0
# NUK_N                                  0                               0
# NUK_U                                  0                               0
# NUK_Uv3                                0                               0
# QAS_A                                  0                               0
# QAS_M               55255
# QAS_U              127450
# QAS_Uv3             21462
# Roof_GEUS            6048
# Roof_PROMICE         4649
# SCO_L              127391
# SCO_U              127851
# SDL                223340
# SDM                226430
# SWC                233669
# SWC_O                4862
# TAS_A               65959
# TAS_L              135849
# TAS_U               65059
# THU_L              109880
# THU_L2               6727
# THU_U               98902
# THU_U2              41647
# TUN                232654
# UPE_L              118445
# UPE_U              118440
# UWN                 21825
# WEG_B                   0
# ZAK_L              130594
# ZAK_U               23798
# ZAK_Uv3              5952

# %%
# Old Data
#df = pd.read_parquet('data\promice_daily.gzip', engine='pyarrow')

# %%
# Old Data
#df[['DepthPressureTransducer(m)',
#       'DepthPressureTransducer_Cor(m)']].groupby(df.file).count()
# Out:
#                 DepthPressureTransducer(m)  DepthPressureTransducer_Cor(m)
# file
# CEN_day_v03                              0                               0
# EGP_day_v03                              0                               0
# KAN_B_day_v03                            0                               0
# KAN_L_day_v03                         4874                            4874
# KAN_M_day_v03                         2878                            2878
# KAN_U_day_v03                            0                               0
# KPC_L_day_v03                         4006                            3535
# KPC_U_day_v03                         4011                            4011
# MIT_day_v03                           4187                            4187
# NUK_K_day_v03                         2716                            2716
# NUK_L_day_v03                         5133                            5133
# NUK_N_day_v03                         1374                            1374
# NUK_U_day_v03                         4321                            4321
# QAS_A_day_v03                            0                               0
# QAS_L_day_v03                         5088                            5088
# QAS_M_day_v03                         1965                            1926
# QAS_U_day_v03                         4799                            4797
# SCO_L_day_v03                         4882                            4882
# SCO_U_day_v03                         4451                            4444
# TAS_A_day_v03                         2994                            2994
# TAS_L_day_v03                         3595                            3357
# TAS_U_day_v03                         2496                            2496
# THU_L_day_v03                         3345                            3345
# THU_U2_day_v03                          72                              72
# THU_U_day_v03                         3448                            3444
# UPE_L_day_v03                         3869                            3866
# UPE_U_day_v03                         4506                            4506

# %%
# Old Data
#df
# Out:
#         Year  MonthOfYear  DayOfMonth  DayOfYear  DayOfCentury  \
# 0       2007            8          20        232          2789
# 1       2007            8          21        233          2790
# 2       2007            8          22        234          2791
# 3       2007            8          23        235          2792
# 4       2007            8          24        236          2793
# ...      ...          ...         ...        ...           ...
# 103704  2015            8           9        221          5700
# 103705  2015            8          10        222          5701
# 103706  2015            8          11        223          5702
# 103707  2015            8          12        224          5703
# 103708  2015            8          13        225          5704
#
#         AirPressure(hPa)  AirTemperature(C)  AirTemperatureHygroClip(C)  \
# 0                    NaN                NaN                         NaN
# 1                 936.34               4.63                        3.67
# 2                 941.60               2.78                        2.07
# 3                 939.17               4.07                        2.96
# 4                 942.43               4.17                        3.55
# ...                  ...                ...                         ...
# 103704            932.30               4.14                        2.88
# 103705            934.46               3.92                        2.73
# 103706            934.42               2.49                        1.16
# 103707            934.07               2.62                        1.20
# 103708               NaN                NaN                         NaN
#
#         RelativeHumidity(%)  SpecificHumidity(g/kg)  ...  \
# 0                       NaN                     NaN  ...
# 1                      85.0                    4.79  ...
# 2                      96.8                    4.78  ...
# 3                      87.1                    4.72  ...
# 4                      79.8                    4.34  ...
# ...                     ...                     ...  ...
# 103704                 55.0                    3.03  ...
# 103705                 56.7                    3.02  ...
# 103706                 62.6                    3.05  ...
# 103707                 70.6                    3.46  ...
# 103708                  NaN                     NaN  ...
#
#         LongitudeGPS_HDOP<1(degW)  ElevationGPS_HDOP<1(m)  \
# 0                             NaN                     NaN
# 1                       49.521549                   588.5
# 2                       49.521583                   586.5
# 3                       49.521667                   587.2
# 4                       49.521667                   587.8
# ...                           ...                     ...
# 103704                  38.866818                   565.6
# 103705                  38.866826                   566.8
# 103706                  38.866839                   566.5
# 103707                  38.866832                   566.3
# 103708                  38.866842                   565.4
#
#         HorDilOfPrecGPS_HDOP<1  LoggerTemperature(C)  FanCurrent(mA)  \
# 0                          NaN                 12.85             NaN
# 1                         0.80                  6.17             NaN
# 2                         0.84                  8.03             NaN
# 3                         0.81                  4.73             NaN
# 4                         0.96                  4.08             NaN
# ...                        ...                   ...             ...
# 103704                    0.81                  4.63           134.2
# 103705                    0.82                  5.40           136.1
# 103706                    0.83                  3.68           138.1
# 103707                    0.85                  2.72           127.2
# 103708                    0.82                  3.34           127.6
#
#         BatteryVoltage(V)           file  Month  Day   Datetime
# 0                     NaN  NUK_L_day_v03      8   20 2007-08-20
# 1                   12.74  NUK_L_day_v03      8   21 2007-08-21
# 2                   12.95  NUK_L_day_v03      8   22 2007-08-22
# 3                   12.76  NUK_L_day_v03      8   23 2007-08-23
# 4                   13.10  NUK_L_day_v03      8   24 2007-08-24
# ...                   ...            ...    ...  ...        ...
# 103704              13.42  TAS_U_day_v03      8    9 2015-08-09
# 103705              13.44  TAS_U_day_v03      8   10 2015-08-10
# 103706              13.39  TAS_U_day_v03      8   11 2015-08-11
# 103707              13.03  TAS_U_day_v03      8   12 2015-08-12
# 103708              13.01  TAS_U_day_v03      8   13 2015-08-13
#
# [103709 rows x 49 columns]

# %% [markdown]
# **Visual Exploration**

# %%
# Comment Nils: For some reason the data is not shown in all visuals? The loop is not working correct

# %%
# Takes some time

for site in df.stid.unique().tolist():
    df = df[df["stid"] == site]
    f1 = plt.figure(figsize=(10, 8))    
    df["z_pt_cor_adj"].plot(label = 'Pressure transducer')
    df["z_surf_1_adj"].plot(label = 'SonicRanger1')
    df["z_surf_2_adj"].plot(label = 'SonicRanger2')
    df["z_surf_combined"].plot(label = 'Summary',
             linestyle='--', linewidth=2, color = 'tab:red')

    plt.legend(prop={'size': 15})
    plt.xlabel('Year',size=20)
    plt.ylabel('Height (m)',size=20)
    plt.title(site,size=20)
    plt.grid()
   # for i, y in enumerate(years):
   #     plt.axvspan(df.index[ind_start[i]],df.index[ind_end[i]], color='orange', alpha=0.1)
# Out:
# C:\Users\nifu18ab\AppData\Local\Temp\3/ipykernel_2392/1578783789.py:3: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
