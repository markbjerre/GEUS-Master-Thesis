# %% [markdown]
# # Surface Mass Balance

# %% [markdown]
# Import relevant Libaries

# %%
# %pip install pyarrow
# %pip install plotly
# %pip update pandas
# Out:
# Requirement already satisfied: pyarrow in /Users/nilsfulde/opt/anaconda3/lib/python3.8/site-packages (11.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /Users/nilsfulde/opt/anaconda3/lib/python3.8/site-packages (from pyarrow) (1.24.2)
# WARNING: You are using pip version 21.3.1; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/nilsfulde/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: plotly in /Users/nilsfulde/opt/anaconda3/lib/python3.8/site-packages (5.6.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/nilsfulde/opt/anaconda3/lib/python3.8/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /Users/nilsfulde/opt/anaconda3/lib/python3.8/site-packages (from plotly) (1.12.0)
# WARNING: You are using pip version 21.3.1; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/nilsfulde/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "update"
# Note: you may need to restart the kernel to use updated packages.

# %%
# Base libraries
import pandas as pd
import numpy as np
import os
import math as math
import datetime
from scipy import stats

# Visualizations
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go

import seaborn as sns

# %%
from scipy.interpolate import interp1d
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %% [markdown]
# Set WD

# %%
import os

from pyrsistent import v
os.getcwd()
#os.chdir('/Users/asgerlyngeholst-hansen/Desktop/GEUS-Master-Thesis/')
#os.chdir('C:\\Users\\nifu18ab\\Desktop\\GEUS-Master-Thesis')
#os.chdir('/Users/nilsfulde/Desktop/GEUS-Master-Thesis')
os.chdir('/Users/nilsfulde/Desktop/Master_Thesis')

# %% [markdown]
# **Load New Promice Data**

# %%
#Function for loading data and converting to datetime 
def load_promice(path_to_file):
    '''
    Loading PROMICE data for a given path into a DataFrame.
    + adding time index
    
    INTPUTS:
        path_to_file: Path to the desired file containing PROMICE data [string]
    
    OUTPUTS:
        df: Dataframe containing PROMICE data for the desired settings [DataFrame]
    '''

    df = pd.read_parquet(path_to_file, engine='pyarrow')
    df['time'] = pd.to_datetime(df.time, utc=True)
    df = df.set_index('time')
    return df

# %%
df = load_promice('data/new_promice/all_promice_data_hourly.parquet.gzip')

# %% [markdown]
# #### Load KM_L

# %%
df = pd.read_csv('data/KAN_L.csv')

# add headers
header = pd.read_csv('metadata/promice_header.csv', sep = ";")
df = df.rename(columns = header.set_index('standard_name')['long_name'])

# %% [markdown]
# **Helper functions**

# %%
#Function for writing to Markdown Report
def Msg(txt):
    f = open("out/Report.md", "a")
    print(txt)
    f.write(txt + "\n")

# %%
#For outlier detecttion and filter 
def hampel(vals_orig, k=7*24, t0=3):
    '''
    vals: pandas series of values from which to remove outliers
    k: size of window (including the sample; 7 is equal to 3 on either side of value)
    '''
    #Make copy so original not edited
    vals=vals_orig.copy()    
    #Hampel Filter
    L= 1.4826
    rolling_median=vals.rolling(k).median()
    difference=np.abs(rolling_median-vals)
    median_abs_deviation=difference.rolling(k).median()
    threshold= t0 *L * median_abs_deviation
    outlier_idx=difference>threshold
    outlier_idx[0:round(k/2)]=False
    vals.loc[outlier_idx]=np.nan
    return(vals)

# %% [markdown]
# #### Correlation and Pairplot (takes long time to run for many variables)

# %%
# Out:
#         air_pressure  air_pressure  air_temperature  air_temperature  \
# 0            932.189           NaN            4.223              NaN
# 1            932.209           NaN            4.213              NaN
# 2            932.147           NaN            4.172              NaN
# 3            932.238           NaN            4.242              NaN
# 4            932.102           NaN            4.263              NaN
# ...              ...           ...              ...              ...
# 126816           NaN           NaN              NaN              NaN
# 126817           NaN           NaN              NaN              NaN
# 126818           NaN           NaN              NaN              NaN
# 126819           NaN           NaN              NaN              NaN
# 126820       913.000           NaN          -13.530              NaN
#
#         relative_humidity  relative_humidity  relative_humidity_corrected  \
# 0                  76.440                NaN                       76.440
# 1                  77.102                NaN                       77.102
# 2                  77.721                NaN                       77.721
# 3                  77.258                NaN                       77.258
# 4                  77.287                NaN                       77.287
# ...                   ...                ...                          ...
# 126816                NaN                NaN                          NaN
# 126817                NaN                NaN                          NaN
# 126818                NaN                NaN                          NaN
# 126819                NaN                NaN                          NaN
# 126820             77.000                NaN                       87.837
#
#         relative_humidity_corrected  specific_humidity  specific_humidity  \
# 0                               NaN              4.225                NaN
# 1                               NaN              4.258                NaN
# 2                               NaN              4.281                NaN
# 3                               NaN              4.276                NaN
# 4                               NaN              4.284                NaN
# ...                             ...                ...                ...
# 126816                          NaN                NaN                NaN
# 126817                          NaN                NaN                NaN
# 126818                          NaN                NaN                NaN
# 126819                          NaN                NaN                NaN
# 126820                          NaN              1.132                NaN
#
#         ...  ice_temperature_at_t11  fan_current  fan_current  \
# 0       ...                     NaN       128.33          NaN
# 1       ...                     NaN       125.43          NaN
# 2       ...                     NaN       125.57          NaN
# 3       ...                     NaN       126.60          NaN
# 4       ...                     NaN       123.43          NaN
# ...     ...                     ...          ...          ...
# 126816  ...                     NaN          NaN          NaN
# 126817  ...                     NaN          NaN          NaN
# 126818  ...                     NaN          NaN          NaN
# 126819  ...                     NaN          NaN          NaN
# 126820  ...                     NaN       158.50          NaN
#
#         depth_of_ice_temperature_t9  depth_of_ice_temperature_t10  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
# ...                             ...                           ...
# 126816                          NaN                           NaN
# 126817                          NaN                           NaN
# 126818                          NaN                           NaN
# 126819                          NaN                           NaN
# 126820                          NaN                           NaN
#
#         depth_of_ice_temperature_t11  z_pt_cor_adj_flag  \
# 0                                NaN                0.0
# 1                                NaN                0.0
# 2                                NaN                0.0
# 3                                NaN                0.0
# 4                                NaN                0.0
# ...                              ...                ...
# 126816                           NaN                0.0
# 126817                           NaN                0.0
# 126818                           NaN                0.0
# 126819                           NaN                0.0
# 126820                           NaN                1.0
#
#         adjusted_ice_surface_height  adjusted_surface_height_1  \
# 0                            -0.012                        NaN
# 1                             0.088                        NaN
# 2                             0.088                        NaN
# 3                             0.087                        NaN
# 4                             0.089                        NaN
# ...                             ...                        ...
# 126816                      -56.668                    -54.735
# 126817                      -56.666                    -54.736
# 126818                      -56.664                    -54.737
# 126819                      -56.662                    -54.738
# 126820                      -56.660                    -54.739
#
#         adjusted_surface_height_2
# 0                           0.074
# 1                           0.067
# 2                           0.065
# 3                           0.061
# 4                           0.061
# ...                           ...
# 126816                    -54.747
# 126817                    -54.749
# 126818                    -54.751
# 126819                    -54.753
# 126820                    -54.755
#
# [126821 rows x 116 columns]

# %%
df.columns
# Out:
# Index([                                        'index',
#                                                 'stid',
#                                         'air_pressure',
#                                      'air_temperature',
#                                    'relative_humidity',
#                          'relative_humidity_corrected',
#                                    'specific_humidity',
#                                           'wind_speed',
#                                  'wind_from_direction',
#                   'surface_downwelling_shortwave_flux',
#         'surface_downwelling_shortwave_flux_corrected',
#                     'surface_upwelling_shortwave_flux',
#           'surface_upwelling_shortwave_flux_corrected',
#                                       'surface_albedo',
#                    'surface_downwelling_longwave_flux',
#                      'surface_upwelling_longwave_flux',
#                                  'cloud_area_fraction',
#                                  'surface_temperature',
#                    'surface_downward_latent_heat_flux',
#                  'surface_downward_sensible_heat_flux',
#                        'distance_to_surface_from_boom',
#              'distance_to_surface_from_stake_assembly',
#                  'depth_of_pressure_transducer_in_ice',
#        'depth_of_pressure_transducer_in_ice_corrected',
#                                        'precipitation',
#                              'precipitation_corrected',
#                                'ice_temperature_at_t1',
#                                'ice_temperature_at_t2',
#                                'ice_temperature_at_t3',
#                                'ice_temperature_at_t4',
#                                'ice_temperature_at_t5',
#                                'ice_temperature_at_t6',
#                                'ice_temperature_at_t7',
#                                'ice_temperature_at_t8',
#                                'platform_view_angle_x',
#                                'platform_view_angle_y',
#                               'platform_azimuth_angle',
#                                         'gps_latitude',
#                                        'gps_longitude',
#                                         'gps_altitude',
#                                             'gps_time',
#                                 'gps_geoid_separation',
#                                          'gps_geounit',
#                                             'gps_hdop',
#                                           'gps_numsat',
#                                                'gps_q',
#                                      'battery_voltage',
#                                                    nan,
#                      'battery_voltage_at_sample_start',
#                                          'fan_current',
#            'frequency_of_precipitation_wire_vibration',
#                                'temperature_of_logger',
#                      'temperature_of_radiation_sensor',
#                                     'message_latitude',
#                                    'message_longitude',
#                                     'surface_height_1',
#                                     'surface_height_2',
#                                    'z_surf_1_adj_flag',
#                                    'z_surf_2_adj_flag',
#                              'surface_height_combined',
#                          'depth_of_ice_temperature_t1',
#                          'depth_of_ice_temperature_t2',
#                          'depth_of_ice_temperature_t3',
#                          'depth_of_ice_temperature_t4',
#                          'depth_of_ice_temperature_t5',
#                          'depth_of_ice_temperature_t6',
#                          'depth_of_ice_temperature_t7',
#                          'depth_of_ice_temperature_t8',
#                               'ice_temperature_at_10m',
#                                         'air_pressure',
#                                      'air_temperature',
#                                    'relative_humidity',
#                          'relative_humidity_corrected',
#                                    'specific_humidity',
#                                           'wind_speed',
#                                  'wind_from_direction',
#                    'surface_downward_latent_heat_flux',
#                  'surface_downward_sensible_heat_flux',
#                        'distance_to_surface_from_boom',
#                                        'precipitation',
#                              'precipitation_corrected',
#                                'ice_temperature_at_t9',
#                               'ice_temperature_at_t10',
#                               'ice_temperature_at_t11',
#                                          'fan_current',
#                          'depth_of_ice_temperature_t9',
#                         'depth_of_ice_temperature_t10',
#                         'depth_of_ice_temperature_t11',
#                                    'z_pt_cor_adj_flag',
#                          'adjusted_ice_surface_height',
#                            'adjusted_surface_height_1',
#                            'adjusted_surface_height_2',
#                                             'Datetime'],
#       dtype='object')

# %%
exclude_list = ["stid", "index", "Datetime", ]

# %%
sns.pairplot(data=df[[column for column in df.columns if column not in exclude_list and not isinstance(column, int)]], hue="Ablation")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 sns.pairplot(data=df[[column for column in df.columns if column not in exclude_list]], hue="Ablation")
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:1989, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1987 # Set up the PairGrid
#    1988 grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 1989 grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    1990                 hue_order=hue_order, palette=palette, corner=corner,
#    1991                 height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    1993 # Add the markers here as PairGrid has figured out how many levels of the
#    1994 # hue variable are needed and we don't want to duplicate that process
#    1995 if markers is not None:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:1155, in PairGrid.__init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1152     warnings.warn(UserWarning(msg))
#    1154 # Sort out the variables that define the grid
# -> 1155 numeric_cols = self._find_numeric_cols(data)
#    1156 if hue in numeric_cols:
#    1157     numeric_cols.remove(hue)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:1568, in PairGrid._find_numeric_cols(self, data)
#    1566 numeric_cols = []
#    1567 for col in data:
# -> 1568     if variable_type(data[col]) == "numeric":
#    1569         numeric_cols.append(col)
#    1570 return numeric_cols
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py:1222, in variable_type(vector, boolean_type)
#    1219     return "categorical"
#    1221 # Special-case all-na data, which is always "numeric"
# -> 1222 if pd.isna(vector).all():
#    1223     return "numeric"
#    1225 # Special-case binary/boolean data, allow caller to determine
#    1226 # This triggers a numpy warning when vector has strings/objects
#    1227 # https://github.com/numpy/numpy/issues/6784
#    (...)
#    1231 # https://github.com/numpy/numpy/issues/13548
#    1232 # This is considered a bug by numpy and will likely go away.
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Increase the size of the heatmap.
plt.figure(figsize=(16, 6))
# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.
heatmap = sns.heatmap(df[[column for column in df.columns if column not in exclude_list and not isinstance(column, int)]].corr(), vmin=-1, vmax=1, annot=True)
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# **PCA**

# %% [markdown]
# **Multivariate Regression**
