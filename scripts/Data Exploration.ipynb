# %%
import os
import pandas as pd
d.set_option('display.float_format', lambda x: '%.3f' % x)

def process_hourly_data(csv_directory="../../PROMICE-AWS-toolbox/out/L4", add_meta_data=False):
        # List all CSV files in the directory
    csv_files = [f for f in os.listdir(csv_directory) if f.endswith('.csv')]

    # Combine all CSV files into a single DataFrame
    dfs = []
    for f in csv_files:
        df = pd.read_csv(os.path.join(csv_directory, f), index_col=False)
        df.insert(0, 'stid', f[:-7])
        dfs.append(df)
    df_hourly = pd.concat(dfs)
    return df_hourly
df = process_hourly_data()

# %%
x
display(df.head(5))
print(df.shape)
# Out:
#    stid                       time  p_u  t_u  rh_u  rh_u_cor  qh_u  wspd_u  \
# 0  CEN1  2017-05-23 10:00:00+00:00  NaN  NaN   NaN       NaN   NaN  17.330
# 1  CEN1  2017-05-23 11:00:00+00:00  NaN  NaN   NaN       NaN   NaN     NaN
# 2  CEN1  2017-05-23 12:00:00+00:00  NaN  NaN   NaN       NaN   NaN     NaN
# 3  CEN1  2017-05-23 13:00:00+00:00  NaN  NaN   NaN       NaN   NaN     NaN
# 4  CEN1  2017-05-23 14:00:00+00:00  NaN  NaN   NaN       NaN   NaN     NaN
#
#    wdir_u  dsr  ...  t_i_10  t_i_11  fan_dc_l  depth_t_i_9  depth_t_i_10  \
# 0 172.500  NaN  ...     NaN     NaN       NaN          NaN           NaN
# 1     NaN  NaN  ...     NaN     NaN       NaN          NaN           NaN
# 2     NaN  NaN  ...     NaN     NaN       NaN          NaN           NaN
# 3     NaN  NaN  ...     NaN     NaN       NaN          NaN           NaN
# 4     NaN  NaN  ...     NaN     NaN       NaN          NaN           NaN
#
#    depth_t_i_11  z_pt_cor_adj_flag  z_pt_cor_adj  z_surf_1_adj  z_surf_2_adj
# 0           NaN                NaN           NaN           NaN           NaN
# 1           NaN                NaN           NaN           NaN           NaN
# 2           NaN                NaN           NaN           NaN           NaN
# 3           NaN                NaN           NaN           NaN           NaN
# 4           NaN                NaN           NaN           NaN           NaN
#
# [5 rows x 92 columns]
# (5820828, 92)

# %%
display(df.describe().apply("{0:.3f}".format))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 display(df.describe().apply("{0:.3f}".format))
#
# File c:\Users\mabj16ac\Anaconda3\lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\mabj16ac\Anaconda3\lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File c:\Users\mabj16ac\Anaconda3\lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File c:\Users\mabj16ac\Anaconda3\lib\site-packages\pandas\core\apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# TypeError: unsupported format string passed to Series.__format__

# %%
print(df.columns)
# Out:
# Index(['stid', 'time', 'p_u', 't_u', 'rh_u', 'rh_u_cor', 'qh_u', 'wspd_u',
#        'wdir_u', 'dsr', 'dsr_cor', 'usr', 'usr_cor', 'albedo', 'dlr', 'ulr',
#        'cc', 't_surf', 'dlhf_u', 'dshf_u', 'z_boom_u', 'z_stake', 'z_pt',
#        'z_pt_cor', 'precip_u', 'precip_u_cor', 't_i_1', 't_i_2', 't_i_3',
#        't_i_4', 't_i_5', 't_i_6', 't_i_7', 't_i_8', 'tilt_x', 'tilt_y', 'rot',
#        'gps_lat', 'gps_lon', 'gps_alt', 'gps_time', 'gps_geoid', 'gps_geounit',
#        'gps_hdop', 'gps_numsat', 'gps_q', 'batt_v', 'batt_v_ini', 'batt_v_ss',
#        'fan_dc_u', 'freq_vw', 't_log', 't_rad', 'msg_lat', 'msg_lon',
#        'z_surf_1', 'z_surf_2', 'z_surf_1_adj_flag', 'z_surf_2_adj_flag',
#        'z_surf_combined', 'depth_t_i_1', 'depth_t_i_2', 'depth_t_i_3',
#        'depth_t_i_4', 'depth_t_i_5', 'depth_t_i_6', 'depth_t_i_7',
#        'depth_t_i_8', 't_i_10m', 'p_l', 't_l', 'rh_l', 'rh_l_cor', 'qh_l',
#        'wspd_l', 'wdir_l', 'dlhf_l', 'dshf_l', 'z_boom_l', 'precip_l',
#        'precip_l_cor', 't_i_9', 't_i_10', 't_i_11', 'fan_dc_l', 'depth_t_i_9',
#        'depth_t_i_10', 'depth_t_i_11', 'z_pt_cor_adj_flag', 'z_pt_cor_adj',
#        'z_surf_1_adj', 'z_surf_2_adj'],
#       dtype='object')
